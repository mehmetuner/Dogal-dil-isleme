# %%
import pandas as pd

# %%
df = pd.read_csv("/content/filmler_clean (1).csv")

# %%
df.head()
# Out:
#                                       film adi  \
# 0                                       Bergen
# 1                                Kirpi Sonic 2
# 2  Fantastik Canavarlar: Dumbledore'un Sırları
# 3                               Aykut Enişte 2
# 4                                      Morbius
#
#                                     ozet ve detaylar  \
# 0  Arabeskin unutulmayan kadın seslerinden biri o...
# 1  Çocuk filmi \n\n\nKirpi Sonic filminin devam h...
# 2  Karanlık büyücü Gellert Grindelwald, büyücülük...
# 3  Aykut Enişte 2, sevdiği kadınla evlilik arifes...
# 4  Morbius, hastalığına deva bulmaya çalışırken b...
#
#                                   tur  \
# 0              ['Dram', 'Biyografik']
# 1     ['Animasyon', 'Aile', 'Macera']
# 2             ['Fantastik', 'Macera']
# 3                          ['Komedi']
# 4  ['Aksiyon', 'Fantastik', 'Macera']
#
#                                            oyuncular  \
# 0  ['Farah Zeynep Abdullah', 'Erdal Beşikçioğlu',...
# 1              ['Jim Carrey', 'James Marsden', None]
# 2   ['Eddie Redmayne', 'Jude Law', 'Mads Mikkelsen']
# 3  ['Cem Gelinoğlu', 'Melis Babadağ', 'Hakan Yılm...
# 4  ['Jared Leto', 'Matt Smith (XI)', 'Adria Arjona']
#
#                           yonetmen  vizyon tarihi     sure  \
# 0  ['Mehmet Binay', 'Caner Alper']    4 Mart 2022  2s 26dk
# 1                  ['Jeff Fowler']   8 Nisan 2022   2s 2dk
# 2                  ['David Yates']  15 Nisan 2022  2s 22dk
# 3                ['Onur Bilgetay']  3 Aralık 2021  1s 55dk
# 4              ['Daniel Espinosa']   1 Nisan 2022  1s 45dk
#
#                                                clean
# 0  arabesk unutmak kadın ses o Bergen inmek hayat...
# 1  çocuk film kirpi Sonic film deva halka o yapım...
# 2  Karanlık büyü Gellert Grindelwald büyü Dünya k...
# 3  Aykut enişte 2 sevmek kadın ev arife kendi tür...
# 4  Morbius hastalık deva bulmak Çalışır bambaşka ...

# %%
oyuncular=df["oyuncular"]
df["clean"]=df["clean"]+oyuncular
clean=df["clean"]

# %%
len(clean)
# Out:
# 5261

# %%
word2idx = {}
idx2word = {}

# %%
i = 0
for cell in clean:
    words = cell.split()
    for word in words:
        if word in word2idx:
            continue
        word2idx[word] = i
        idx2word[i] = word
        i += 1

# %%
word2idx
# Out:
# {'arabesk': 0,
#  'unutmak': 1,
#  'kadın': 2,
#  'ses': 3,
#  'o': 4,
#  'Bergen': 5,
#  'inmek': 6,
#  'hayat': 7,
#  'anlatmak': 8,
#  'film': 9,
#  'olmak': 10,
#  'bilmek': 11,
#  'belgi': 12,
#  'Ankara': 13,
#  'dan': 14,
#  'ada': 15,
#  'ora': 16,
#  'yaşamak': 17,
#  'aşk': 18,
#  'ardından': 19,
#  'ebediyet': 20,
#  'uzanmak': 21,
#  'öykü': 22,
#  '1959': 23,
#  'yıl': 24,
#  'Mersin': 25,
#  'yemek': 26,
#  'çocuklu': 27,
#  'bir': 28,
#  'aile': 29,
#  'küçük': 30,
#  'çocuk': 31,
#  'Dünya': 32,
#  'gelir': 33,
#  'Anne': 34,
#  'baba': 35,
#  'boşanma': 36,
#  'kök': 37,
#  'biçim': 38,
#  'değişmek': 39,
#  'başka': 40,
#  'kimse': 41,
#  'yok': 42,
#  'yoksun': 43,
#  'iç': 44,
#  'dermek': 45,
#  'boşluk': 46,
#  'açar': 47,
#  'ötmek': 48,
#  'yan': 49,
#  'konservatuar': 50,
#  'girmek': 51,
#  'başarı': 52,
#  'katmer': 53,
#  'gelmek': 54,
#  'umut': 55,
#  'ilk': 56,
#  'Abdullah': 57,
#  'tan': 58,
#  'ayırmak': 59,
#  'yar': 60,
#  'almak': 61,
#  'ama': 62,
#  'büyük': 63,
#  'güç': 64,
#  'yetenek': 65,
#  'nın': 66,
#  'prestij': 67,
#  'mekân': 68,
#  'Feyman': 69,
#  'Kulüp': 70,
#  'Te': 71,
#  'keşfetmek': 72,
#  'Birlik': 73,
#  'parlamak': 74,
#  'Genç': 75,
#  'yıldız': 76,
#  'E': 77,
#  'dönüşmek': 78,
#  'ancak': 79,
#  'zaman': 80,
#  'koşul': 81,
#  'yapılanmak': 82,
#  'kontrat': 83,
#  'sebep': 84,
#  'süre': 85,
#  'çalışmak': 86,
#  'gider': 87,
#  'müzikhol': 88,
#  'sahne': 89,
#  'Müzik': 90,
#  'tarz': 91,
#  'zor': 92,
#  'kalmak': 93,
#  'daha': 94,
#  'sonra': 95,
#  'ev': 96,
#  'halis': 97,
#  'serbest': 98,
#  'karşılaşmak': 99,
#  'manipülatif': 100,
#  'olay': 101,
#  'dizi': 102,
#  'bulmak': 103,
#  'kendi': 104,
#  'le': 105,
#  'yapmak': 106,
#  'düşlemek': 107,
#  'tersinmek': 108,
#  'i': 109,
#  'koparmak': 110,
#  'şiddet': 111,
#  'do': 112,
#  'gün': 113,
#  'tüm': 114,
#  'yalnız': 115,
#  'kariyer': 116,
#  'güzel': 117,
#  'yerinde': 118,
#  'kezzap': 119,
#  'saldırı': 120,
#  'uğramak': 121,
#  'göz': 122,
#  'kaybetmek': 123,
#  'trajedi': 124,
#  'rağmen': 125,
#  'dönmek': 126,
#  'olağanüstü': 127,
#  'şarkı': 128,
#  'Türkiye': 129,
#  'çap': 130,
#  'Şöhret': 131,
#  'tehdit': 132,
#  'taciz': 133,
#  'seyretmek': 134,
#  'gerilim': 135,
#  'ilişki': 136,
#  'gitmek': 137,
#  'Geller': 138,
#  'deva': 139,
#  'etmek': 140,
#  'korku': 141,
#  'son': 142,
#  'kesinmek': 143,
#  'te': 144,
#  'kurtulmak': 145,
#  'düşünmek': 146,
#  'yolcu': 147,
#  'silâh': 148,
#  'ağır': 149,
#  'yaralamak': 150,
#  'henüz': 151,
#  '30': 152,
#  'yaş': 153,
#  'ölmek': 154,
#  'kurban': 155,
#  'kraliçe': 156,
#  'insan': 157,
#  'kalp': 158,
#  'kazımak': 159,
#  'Dram': 160,
#  "Biyografik['Farah": 161,
#  'Zeynep': 162,
#  "Abdullah',": 163,
#  "'Erdal": 164,
#  "Beşikçioğlu',": 165,
#  "'Tilbe": 166,
#  "Saran']['Farah": 167,
#  "Saran']": 168,
#  'kirpi': 169,
#  'Sonic': 170,
#  'halka': 171,
#  'yapım': 172,
#  'İnsa': 173,
#  'atılmak': 174,
#  'macera': 175,
#  'konu': 176,
#  'Green': 177,
#  'Hills': 178,
#  'yerleşmek': 179,
#  'tek': 180,
#  'istek': 181,
#  'gerçek': 182,
#  'kahraman': 183,
#  'gerekmek': 184,
#  'özellik': 185,
#  'sahip': 186,
#  'kanıtlamak': 187,
#  'sınav': 188,
#  'Dr': 189,
#  'Robotnik': 190,
#  'ortak': 191,
#  'Knuckes': 192,
#  'medeniyet': 193,
#  'zümrüt': 194,
#  'aramak': 195,
#  'geri': 196,
#  'dönme': 197,
#  'başlamak': 198,
#  'yanlış': 199,
#  'el': 200,
#  'geçmek': 201,
#  'engellemek': 202,
#  'yardım': 203,
#  'Tails': 204,
#  'çıkar': 205,
#  'Animasyon': 206,
#  'Aile': 207,
#  "Macera['Jim": 208,
#  "Carrey',": 209,
#  "'James": 210,
#  "Marsden',": 211,
#  "None]['Jim": 212,
#  'None]': 213,
#  'Karanlık': 214,
#  'büyü': 215,
#  'Gellert': 216,
#  'Grindelwald': 217,
#  'kontrol': 218,
#  'elemek': 219,
#  'geçirmek': 220,
#  'hareket': 221,
#  'geçmiş': 222,
#  'bun': 223,
#  'öğrenmek': 224,
#  'profesör': 225,
#  'Albus': 226,
#  'Dumbledore': 227,
#  'önce': 228,
#  'baş': 229,
#  'durmak': 230,
#  'Çalışır': 231,
#  'başarmak': 232,
#  'ara': 233,
#  'cadı': 234,
#  'cesur': 235,
#  'Muggle': 236,
#  'fırın': 237,
#  'oluşmak': 238,
#  'ekip': 239,
#  'yönetim': 240,
#  'Büyüzoolog': 241,
#  'Newt': 242,
#  'Scamander': 243,
#  'A': 244,
#  'emanet': 245,
#  'tehlike': 246,
#  'görev': 247,
#  'üstlenmek': 248,
#  'ekmek': 249,
#  'canavar': 250,
#  'mücadele': 251,
#  'sayı': 252,
#  'Artan': 253,
#  'un': 254,
#  'mürit': 255,
#  'savaşmak': 256,
#  'risk': 257,
#  'karşı': 258,
#  'kadar': 259,
#  'kenar': 260,
#  'beklemek': 261,
#  'Fantastik': 262,
#  "Macera['Eddie": 263,
#  "Redmayne',": 264,
#  "'Jude": 265,
#  "Law',": 266,
#  "'Mads": 267,
#  "Mikkelsen']['Eddie": 268,
#  "Mikkelsen']": 269,
#  'Aykut': 270,
#  'enişte': 271,
#  '2': 272,
#  'sevmek': 273,
#  'arife': 274,
#  'türlü': 275,
#  'bulamak': 276,
#  'hikâye': 277,
#  'Gülşah': 278,
#  'hazırlık': 279,
#  'I': 280,
#  'elinden': 281,
#  'kaçırmak': 282,
#  'karar': 283,
#  'Atabeyoğlu': 284,
#  'nin': 285,
#  'damat': 286,
#  'oldukça': 287,
#  'heyecan': 288,
#  'duru': 289,
#  'plan': 290,
#  'alt': 291,
#  'üst': 292,
#  'eskimek': 293,
#  'Talat': 294,
#  'In': 295,
#  'düğü': 296,
#  'Orta': 297,
#  'çıkmak': 298,
#  'iş': 299,
#  'karışmak': 300,
#  'iyi': 301,
#  'niyet': 302,
#  'saf': 303,
#  'nedeniyle': 304,
#  'açılamak': 305,
#  'belâ': 306,
#  'çalışan': 307,
#  'Mi': 308,
#  "Komedi['Cem": 309,
#  "Gelinoğlu',": 310,
#  "'Melis": 311,
#  "Babadağ',": 312,
#  "'Hakan": 313,
#  "Yılmaz']['Cem": 314,
#  "Yılmaz']": 315,
#  'Morbius': 316,
#  'hastalık': 317,
#  'bambaşka': 318,
#  'var': 319,
#  'bili': 320,
#  'Michael': 321,
#  'muzdarip': 322,
#  'nadir': 323,
#  'görü': 324,
#  'kan': 325,
#  'deney': 326,
#  'yöntem': 327,
#  'tedavi': 328,
#  'elektroşok': 329,
#  'terapi': 330,
#  'vampir': 331,
#  'yarasa': 332,
#  'kul': 333,
#  'korkunç': 334,
#  'sonuçlamak': 335,
#  'artık': 336,
#  'hiçbir': 337,
#  'eski': 338,
#  'birçok': 339,
#  'kala': 340,
#  'sürekli': 341,
#  'kana': 342,
#  'ihtiyaç': 343,
#  'ışık': 344,
#  'imkân': 345,
#  'bu': 346,
#  'sorun': 347,
#  'sır': 348,
#  'insanüstü': 349,
#  'Aksiyon': 350,
#  "Macera['Jared": 351,
#  "Leto',": 352,
#  "'Matt": 353,
#  'Smith': 354,
#  "(XI)',": 355,
#  "'Adria": 356,
#  "Arjona']['Jared": 357,
#  "Arjona']": 358,
#  'Kırmız': 359,
#  'ergen': 360,
#  'getirmek': 361,
#  'sıkışmak': 362,
#  'üç': 363,
#  'Mei': 364,
#  'Lee': 365,
#  'odak': 366,
#  'beklenti': 367,
#  'beraberinde': 368,
#  'karmaşmak': 369,
#  '13': 370,
#  'kız': 371,
#  'baskı': 372,
#  'korumak': 373,
#  'Ming': 374,
#  'Uzak': 375,
#  'istemek': 376,
#  'Talih': 377,
#  'hem': 378,
#  'vücut': 379,
#  'değişik': 380,
#  'uğraşmak': 381,
#  'heyecanlanmak': 382,
#  'dev': 383,
#  'panda': 384,
#  'Komedi[None,': 385,
#  'None,': 386,
#  'None][None,': 387,
#  '20': 388,
#  'Li': 389,
#  'hal': 390,
#  'lise': 391,
#  'öğrenci': 392,
#  'müzeyyen': 393,
#  'çoğu': 394,
#  'Bekir': 395,
#  'Ebru': 396,
#  'Hazerhan': 397,
#  'Ferdane': 398,
#  'kadir': 399,
#  'de': 400,
#  'arkadaş': 401,
#  'Grub': 402,
#  'geçirir': 403,
#  'bütün': 404,
#  'günah': 405,
#  'paylaşmak': 406,
#  'iletişim': 407,
#  'görmek': 408,
#  'dok': 409,
#  'beri': 410,
#  'haberdar': 411,
#  'kardeş': 412,
#  'ali': 413,
#  'yirmi': 414,
#  'yılmak': 415,
#  'yasak': 416,
#  'hamil': 417,
#  'kalın': 418,
#  'terketmek': 419,
#  'hepsi': 420,
#  'yen': 421,
#  'yarıyıl': 422,
#  'Tati': 423,
#  'fırsat': 424,
#  'tanışmak': 425,
#  'Antalya': 426,
#  'arka': 427,
#  'Sokak': 428,
#  'Yi': 429,
#  'kabul': 430,
#  'dâhil': 431,
#  'iki': 432,
#  'amaç': 433,
#  'birinci': 434,
#  'bol': 435,
#  'götürmek': 436,
#  'Yaşam': 437,
#  'standart': 438,
#  'erişmek': 439,
#  'sağlamak': 440,
#  'diğer': 441,
#  "Dram['Hazar": 442,
#  "Ergüçlü',": 443,
#  "'Ozan": 444,
#  "Uygun',": 445,
#  "'Halil": 446,
#  "Babür']['Hazar": 447,
#  "Babür']": 448,
#  'kesişmek': 449,
#  'ermek': 450,
#  'Trabzon': 451,
#  'Maçka': 452,
#  'terörist': 453,
#  'Mehmet': 454,
#  'çatışmak': 455,
#  'sırasında': 456,
#  'bülbül': 457,
#  'şehit': 458,
#  'astsubay': 459,
#  'kıdem': 460,
#  'başçavuş': 461,
#  'Ferhat': 462,
#  'Gedik': 463,
#  "Aksiyon['İsmail": 464,
#  "Hacıoğlu',": 465,
#  "'Rahman": 466,
#  "Başel',": 467,
#  "'Alayça": 468,
#  "Öztürk']['İsmail": 469,
#  "Öztürk']": 470,
#  'örümcek': 471,
#  'kimlik': 472,
#  'açık': 473,
#  'vermek': 474,
#  'doktor': 475,
#  'Strange': 476,
#  'ifşa': 477,
#  'halk': 478,
#  'ön': 479,
#  'sermek': 480,
#  'kaos': 481,
#  'Peter': 482,
#  'aynı': 483,
#  'suç': 484,
#  'lanse': 485,
#  'edi': 486,
#  'MJ': 487,
#  'Ned': 488,
#  'olumsuz': 489,
#  'etkilemek': 490,
#  'şahit': 491,
#  'üniversite': 492,
#  'şans': 493,
#  'seyir': 494,
#  'ister': 495,
#  'yakarmak': 496,
#  'on': 497,
#  'nü': 498,
#  'büyümek': 499,
#  'May': 500,
#  'Happy': 501,
#  'hatırlamak': 502,
#  'kişi': 503,
#  'parametre': 504,
#  'Macera': 505,
#  "Fantastik['Tom": 506,
#  "Holland',": 507,
#  "'Zendaya',": 508,
#  "'Benedict": 509,
#  "Cumberbatch']['Tom": 510,
#  "Cumberbatch']": 511,
#  'The': 512,
#  'batman': 513,
#  'suçlu': 514,
#  'salâ': 515,
#  'Riddler': 516,
#  'isim': 517,
#  'Seri': 518,
#  'katil': 519,
#  'salmak': 520,
#  'Bruce': 521,
#  'Wayne': 522,
#  'Gotham': 523,
#  'City': 524,
#  'karanlık': 525,
#  'sürüklemek': 526,
#  'Gizem': 527,
#  'şehir': 528,
#  'seçkin': 529,
#  'hedef': 530,
#  'diz': 531,
#  'sadist': 532,
#  'hain': 533,
#  'iz': 534,
#  'sürme': 535,
#  'İpuçlarınını': 536,
#  'peşin': 537,
#  'Gide': 538,
#  'yol': 539,
#  'süreç': 540,
#  'Catwoman': 541,
#  'Selina': 542,
#  'Kyle': 543,
#  'penguen': 544,
#  'Oswald': 545,
#  'Cobblepot': 546,
#  'Carmine': 547,
#  'Falcone': 548,
#  'karakter': 549,
#  'kurmak': 550,
#  'maske': 551,
#  'düşürmek': 552,
#  'Ni': 553,
#  'huzur': 554,
#  'kavuşmak': 555,
#  'girişmek': 556,
#  'Polisiye': 557,
#  "Gerilim['Robert": 558,
#  "Pattinson',": 559,
#  "'Zoë": 560,
#  "Kravitz',": 561,
#  "'Paul": 562,
#  "Dano']['Robert": 563,
#  "Dano']": 564,
#  'taşımak': 565,
#  'yer': 566,
#  'Sherlock': 567,
#  'kurgu': 568,
#  'dedektif': 569,
#  'rol': 570,
#  'ün': 571,
#  'Wikileaks': 572,
#  'beşinci': 573,
#  'kuvvet': 574,
#  'bilinmez': 575,
#  'doğru': 576,
#  'star': 577,
#  'Trek': 578,
#  'Imitation': 579,
#  'Game': 580,
#  'Enigma': 581,
#  'Benedict': 582,
#  'Cumberbatch': 583,
#  'yönetmek': 584,
#  'Scott': 585,
#  'Derrickson': 586,
#  'kamera': 587,
#  'Arkas': 588,
#  'Sadık': 589,
#  'us': 590,
#  'Wong': 591,
#  "Macera['Benedict": 592,
#  "Cumberbatch',": 593,
#  "'Elizabeth": 594,
#  "Olsen',": 595,
#  "'Rachel": 596,
#  "McAdams']['Benedict": 597,
#  "McAdams']": 598,
#  'Dilberay': 599,
#  '2019': 600,
#  'veda': 601,
#  'dilber': 602,
#  'aymak': 603,
#  'Kahramanmaraş': 604,
#  'Ta': 605,
#  'sekiz': 606,
#  'çadır': 607,
#  'para': 608,
#  'karşılık': 609,
#  'satmak': 610,
#  'Sahib': 611,
#  'tutku': 612,
#  'Şark': 613,
#  'söylemekti': 614,
#  'yüz': 615,
#  'dayak': 616,
#  'işkence': 617,
#  'çek': 618,
#  'se': 619,
#  'Güç': 620,
#  'adım': 621,
#  'At': 622,
#  'boyunca': 623,
#  'zirve': 624,
#  'dip': 625,
#  'vurmak': 626,
#  'düşmek': 627,
#  'kuyu': 628,
#  'söylemek': 629,
#  'çıktı': 630,
#  'Biyografik': 631,
#  "Dram['Büşra": 632,
#  "Pekin',": 633,
#  "'Zeliha": 634,
#  "Kendirci',": 635,
#  "'Nursel": 636,
#  "Köse']['Büşra": 637,
#  "Köse']": 638,
#  'doru': 639,
#  'orman': 640,
#  'kurtarmak': 641,
#  'Karatay': 642,
#  'Alaca': 643,
#  'hayvan': 644,
#  'sirk': 645,
#  'üzerine': 646,
#  'yak': 647,
#  'yı': 648,
#  'geçer': 649,
#  'zeki': 650,
#  'saye': 651,
#  'kurtaran': 652,
#  'sıra': 653,
#  'sürpriz': 654,
#  'kaçar': 655,
#  'Bebek': 656,
#  'şempanze': 657,
#  'Şöbi': 658,
#  'Animasyon[None,': 659,
#  '25': 660,
#  'Ge': 661,
#  'gelecek': 662,
#  'geçen': 663,
#  'demek': 664,
#  'Will': 665,
#  'Salas': 666,
#  'Justin': 667,
#  'Timberlake': 668,
#  'hata': 669,
#  'sonuç': 670,
#  'cinayet': 671,
#  'hüküm': 672,
#  'giymek': 673,
#  'hapishane': 674,
#  'sistem': 675,
#  'çökermek': 676,
#  'zira': 677,
#  'rahatlıkla': 678,
#  'Zeng': 679,
#  'sonsuz': 680,
#  'kalarak': 681,
#  'fakir': 682,
#  'üstelik': 683,
#  'eklemek': 684,
#  'Güçs': 685,
#  'üzmek': 686,
#  'sade': 687,
#  'kalabilmek': 688,
#  'dilenmek': 689,
#  'ödünç': 690,
#  'hatta': 691,
#  'bazen': 692,
#  'çalmak': 693,
#  'yoz': 694,
#  'kaldırmak': 695,
#  'başrol': 696,
#  'Döne': 697,
#  'sinema': 698,
#  'yönelmek': 699,
#  'Scarlett': 700,
#  'Johansson': 701,
#  'anmak': 702,
#  'Amanda': 703,
#  'Seyfried': 704,
#  'oyun': 705,
#  'kadro': 706,
#  'Olivia': 707,
#  'Wild': 708,
#  'Alex': 709,
#  'Pettyfer': 710,
#  'Cillian': 711,
#  'Murphy': 712,
#  'Gattaca': 713,
#  'S1m0ne': 714,
#  'Lord': 715,
#  'of': 716,
#  'War': 717,
#  'yazmak': 718,
#  'Truman': 719,
#  'Show': 720,
#  'terminal': 721,
#  'senaryo': 722,
#  'kale': 723,
#  'ala': 724,
#  'Andrew': 725,
#  'Niccol': 726,
#  'proje': 727,
#  'yaratmak': 728,
#  'Bilimkurgu': 729,
#  'Gerilim': 730,
#  "Aksiyon['Amanda": 731,
#  "Seyfried',": 732,
#  "'Justin": 733,
#  "Timberlake',": 734,
#  "'Cillian": 735,
#  "Murphy']['Amanda": 736,
#  "Murphy']": 737,
#  'edebiyat': 738,
#  'Anastasia': 739,
#  'Steel': 740,
#  'çeki': 741,
#  'Christian': 742,
#  'Grey': 743,
#  'röportaj': 744,
#  'görüşmek': 745,
#  'tavır': 746,
#  'biraz': 747,
#  'mesafe': 748,
#  'yakışık': 749,
#  'Cazibe': 750,
#  'koymak': 751,
#  'çekim': 752,
#  'bırakmak': 753,
#  'fakat': 754,
#  'şe': 755,
#  'Doyum': 756,
#  'nokta': 757,
#  'Ulaş': 758,
#  'seks': 759,
#  'söz': 760,
#  'gizli': 761,
#  'şehvet': 762,
#  'sapmak': 763,
#  'mı': 764,
#  'L': 765,
#  'James': 766,
#  'liste': 767,
#  'ad': 768,
#  'roman': 769,
#  'Uyar': 770,
#  'yönetmen': 771,
#  'sam': 772,
#  'Taylor': 773,
#  'Johnson': 774,
#  'Jamie': 775,
#  'Dornan': 776,
#  'Dakota': 777,
#  'Romantik': 778,
#  "Gerilim['Jamie": 779,
#  "Dornan',": 780,
#  "'Dakota": 781,
#  "Johnson',": 782,
#  "'Jennifer": 783,
#  "Ehle']['Jamie": 784,
#  "Ehle']": 785,
#  'Recep': 786,
#  'İvedik': 787,
#  '6': 788,
#  'Konya': 789,
#  'Kenya': 790,
#  'davet': 791,
#  'kuru': 792,
#  'fasulye': 793,
#  'festival': 794,
#  'çağırılmaktadır': 795,
#  'memnuniyet': 796,
#  'karşılamak': 797,
#  'Nurullah': 798,
#  'yolmak': 799,
#  'yerinmek': 800,
#  'seyahat': 801,
#  'acente': 802,
#  'Arar': 803,
#  'coğrafya': 804,
#  'düşman': 805,
#  'yerli': 806,
#  'kabile': 807,
#  'has': 808,
#  'vahşî': 809,
#  'dünyada': 810,
#  'ayak': 811,
#  'birbiri': 812,
#  'ilginç': 813,
#  "Komedi['Şahan": 814,
#  "Gökbakar',": 815,
#  "'Nurullah": 816,
#  "Çelebi',": 817,
#  "'Somer": 818,
#  "Karvan']['Şahan": 819,
#  "Karvan']": 820,
#  'milyoner': 821,
#  'sandık': 822,
#  'kolay': 823,
#  'olmaz': 824,
#  'yeniden': 825,
#  'çift': 826,
#  'barışmak': 827,
#  'bitmek': 828,
#  'şeytan': 829,
#  'yüzleşmek': 830,
#  'kalırken': 831,
#  'öfke': 832,
#  'kıskanç': 833,
#  'Ty': 834,
#  'Hoechlin': 835,
#  'kim': 836,
#  'Basinger': 837,
#  'Marcia': 838,
#  'Gay': 839,
#  'Harden': 840,
#  'Bella': 841,
#  'Heathcote': 842,
#  "Erotik['Dakota": 843,
#  "'Jamie": 844,
#  "'Bella": 845,
#  "Heathcote']['Dakota": 846,
#  "Heathcote']": 847,
#  'Day': 848,
#  'sevi': 849,
#  'kabadayı': 850,
#  'adalet': 851,
#  'duygu': 852,
#  'Cesaret': 853,
#  'merhamet': 854,
#  'haylaz': 855,
#  'bıkmak': 856,
#  'taraf': 857,
#  'köy': 858,
#  'İstanbul': 859,
#  'göndermek': 860,
#  'kahve': 861,
#  'Seyfi': 862,
#  'yanında': 863,
#  'ailemine': 864,
#  'yükselmek': 865,
#  "Dram['Ufuk": 866,
#  "Bayraktar',": 867,
#  "'Gizem": 868,
#  "Karaca',": 869,
#  "'Ahmet": 870,
#  "Varlı']['Ufuk": 871,
#  "Varlı']": 872,
#  'kaymak': 873,
#  'yazar': 874,
#  'Loretta': 875,
#  'Sage': 876,
#  'inziva': 877,
#  'çekilmek': 878,
#  'Dash': 879,
#  'canlanmak': 880,
#  'adamak': 881,
#  'kapak': 882,
#  'Mode': 883,
#  'popüler': 884,
#  'egzotik': 885,
#  'Hakk': 886,
#  'kitap': 887,
#  'tanıt': 888,
#  'turne': 889,
#  'eksantrik': 890,
#  'milyarder': 891,
#  'antik': 892,
#  'hazine': 893,
#  'Vakit': 894,
#  'ant': 895,
#  'Komedi': 896,
#  "Macera['Sandra": 897,
#  "Bullock',": 898,
#  "'Channing": 899,
#  "Tatum',": 900,
#  "'Daniel": 901,
#  "Radcliffe']['Sandra": 902,
#  "Radcliffe']": 903,
#  'Üzer': 904,
#  'Uygu': 905,
#  'yetki': 906,
#  'kurtulup': 907,
#  'şeytanî': 908,
#  'bulunmak': 909,
#  'Yüzük': 910,
#  'hükümet': 911,
#  'yakalamak': 912,
#  'devlet': 913,
#  'Eggman': 914,
#  'kasaba': 915,
#  'şerif': 916,
#  'Tom': 917,
#  'Wachowski': 918,
#  'kaçmak': 919,
#  "Aile['Jim": 920,
#  "Marsden']['Jim": 921,
#  "Marsden']": 922,
#  'kuzey': 923,
#  'öldürmek': 924,
#  'intikam': 925,
#  'Viking': 926,
#  'prens': 927,
#  'kral': 928,
#  'Aurvandil': 929,
#  'imparator': 930,
#  'oğul': 931,
#  'Amleth': 932,
#  'devretmek': 933,
#  'üveymek': 934,
#  'Fjölnir': 935,
#  'taht': 936,
#  'amca': 937,
#  'Gudrun': 938,
#  'U': 939,
#  'Görür': 940,
#  'kurtaracağına': 941,
#  'yem': 942,
#  'Slav': 943,
#  'akın': 944,
#  'savaşçı': 945,
#  'Olur': 946,
#  'kâhin': 947,
#  'tutmak': 948,
#  "Tarihi['Alexander": 949,
#  "Skarsgård',": 950,
#  "'Nicole": 951,
#  "Kidman',": 952,
#  "'Claes": 953,
#  "Bang']['Alexander": 954,
#  "Bang']": 955,
#  'Dune': 956,
#  'çöl': 957,
#  'gezegen': 958,
#  'Arrakis': 959,
#  'Paul': 960,
#  'Atreides': 961,
#  'galâksi': 962,
#  'fark': 963,
#  'rakip': 964,
#  'feodal': 965,
#  'çok': 966,
#  'değerli': 967,
#  'kaynak': 968,
#  'üretmek': 969,
#  'asil': 970,
#  'dere': 971,
#  'talep': 972,
#  'baharat': 973,
#  'veri': 974,
#  'Kaynak': 975,
#  'yük': 976,
#  'bilinç': 977,
#  'Uz': 978,
#  'Sunar': 979,
#  'ciddi': 980,
#  'yanmak': 981,
#  'etki': 982,
#  'ayrı': 983,
#  'yıldızlararası': 984,
#  'gezinmek': 985,
#  'tır': 986,
#  'Harkonen': 987,
#  'tuzak': 988,
#  'darmadağın': 989,
#  'olarak': 990,
#  'firarî': 991,
#  'kazanmak': 992,
#  'isyan': 993,
#  'evre': 994,
#  'ihtimalî': 995,
#  'yakalayacaktır': 996,
#  'Frank': 997,
#  'Herbert': 998,
#  '1965': 999,
#  ...}

# %%
import numpy as np

# %%
film_sayisi = len(clean)
vocab_size = len(word2idx)

# %%
filmler = np.zeros((film_sayisi, vocab_size))

# %%
filmler.shape
# Out:
# (5261, 44683)

# %%
for i, cell in enumerate(clean):
    words = cell.split()
    for word in words:
        wordIndex = word2idx[word]
        filmler[i][wordIndex] += 1

# %%
doc_frequencies = {}

# %%
for word in word2idx:
    doc_count = 0
    for film in clean:
        if word in film:
            doc_count += 1
    
    doc_frequencies[word] = doc_count

# %%
sorted_frequencies = sorted(doc_frequencies, key=doc_frequencies.get, reverse=True)

# %%
for word in sorted_frequencies[:10]:
    print(word, doc_frequencies[word])
# Out:
# o 5261
# i 5261
# l 5261
# ak 5246
# an 5244
# ek 5240
# er 5233
# ü 5194
# bi 5178
# ya 5151

# %%
filmler_tf_idf = np.zeros((film_sayisi, vocab_size))
film_sayisi = len(clean)

for i, film in enumerate(filmler):
    if i % 1000 == 0:
        print(f"{i} inci film işleniyor...")
    for j, tf in enumerate(film):
        idf = 0
        if tf > 0:
            idf = np.log(film_sayisi / (doc_frequencies[idx2word[j]] + 1)) + 1
        tf_idf_score = tf * idf
        filmler_tf_idf[i][j] = tf_idf_score
# Out:
# 0 inci film işleniyor...
# 1000 inci film işleniyor...
# 2000 inci film işleniyor...
# 3000 inci film işleniyor...
# 4000 inci film işleniyor...
# 5000 inci film işleniyor...

# %%
def cos_sim(v1, v2):
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

# %%
def film_2_str(row_index):
    film = df.iloc[row_index]
    adi = film['film adi']
    turu = film['tur']
    ozet = film['ozet ve detaylar']
    if len(ozet) > 150:
        ozet = ozet[:150] + "..."

    return f"Film adı: {adi} \nTürü: {turu} \nÖzeti: {ozet}"

# %%
def most_similar_films(film_adi, benzer_film_sayisi):
    film_indexi = df[df["film adi"] == film_adi].index[0]
    print("Aranan Film:")
    print(film_2_str(film_indexi))
    print()
    print("* " * 30)
    print()

    benzerlikler = []
    sorgu_film = filmler_tf_idf[film_indexi]
    for vec in filmler_tf_idf:
        benzerlik = cos_sim(sorgu_film, vec)
        benzerlikler.append(benzerlik)
    
    en_benzer_film_indexleri = (- np.array(benzerlikler)).argsort()[:benzer_film_sayisi + 1]
    print("Benzer Filmler:\n")
    for i, film_idx in enumerate(en_benzer_film_indexleri[1:]):
        print(str(i+1) + ") " + film_2_str(film_idx))
        print()
        print("- " * 20)
        print()

# %%
most_similar_films("Kirpi Sonic 2", 3)
# Out:
# Aranan Film:
# Film adı: Kirpi Sonic 2
# Türü: ['Animasyon', 'Aile', 'Macera']
# Özeti: Çocuk filmi
#
#
# Kirpi Sonic filminin devam halkası olan yapımda, insan biçiminde bir kirpi olan Sonic'in atıldığı maceralar konu ediliyor. Green Hills’...
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#
# Benzer Filmler:
#
# 1) Film adı: Kirpi Sonic
# Türü: ['Macera', 'Aile']
# Özeti: 6 yaş ve üzeri çocuklar için uygun film
#
#
#
# Kirpi Sonic, peşine düşen yetkililerden kurtulup, şeytani doktorun elinde bulunan yüzükleri geri almaya çal...
#
# - - - - - - - - - - - - - - - - - - - -
#
# 2) Film adı: Kirpi Latte ve Büyülü Taş
# Türü: ['Animasyon', 'Aile']
# Özeti: Çocuk filmi
#
#
# Kirpi Latte ve Büyülü Taş, yaşadıkları ormanı kuraklıktan kurtarmak için en yakın arkadaşı sincap ile macera dolu bir yolculuğa çıkan b...
#
# - - - - - - - - - - - - - - - - - - - -
#
# 3) Film adı: Unutulmaz Aşk
# Türü: ['Romantik', 'Dram']
# Özeti: Dawson ve Amanda lisede birbirlerine aşık olan ancak yolları ayrıldıktan sonra bir daha görüşmeyen iki eski aşıktır. Lise bitmiş ve aradan 20 yıl geçm...
#
# - - - - - - - - - - - - - - - - - - - -
